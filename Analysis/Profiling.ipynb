# %%
from ydata_profiling import ProfileReport
import pandas as pd

# Load your dataset
df = pd.read_csv("M:\ML End Sem\Datasets\Social_media_impact_on_life.csv")

# Create profile report
profile = ProfileReport(df, explorative=True)

# Display report in Colab
profile.to_file("report.html")
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\M'
# <>:5: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\mohit\AppData\Local\Temp\ipykernel_16536\4194704013.py:5: SyntaxWarning: invalid escape sequence '\M'
#   df = pd.read_csv("M:\ML End Sem\Datasets\Social_media_impact_on_life.csv")
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 11/11 [00:00<00:00, 212.03it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
